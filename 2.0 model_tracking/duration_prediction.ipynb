# %%
# import dependencies
import pandas as pd
import seaborn as sns
import pickle
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error, r2_score

import mlflow

# %%
mlflow.set_tracking_uri("sqlite:///mydb.sqlite")
#mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='file:///C:/Users/AIDOO K. ENOCH/Documents/GitHub/RGT/MLOPS/mlruns/1', creation_time=1703064795646, experiment_id='1', last_update_time=1703064795646, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
# A function for reading the dataset
# Returns a dataframe
def read_dataframe(filename):
    df = pd.read_parquet(filename) 

    df['lpep_dropoff_datetime']= pd.to_datetime(df.lpep_dropoff_datetime)
    df['lpep_pickup_datetime'] = pd.to_datetime(df.lpep_pickup_datetime)
    
    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda x: x.total_seconds() / 60)
    
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    
    categorical = ['PULocationID', 'DOLocationID']
    numerical   = ['trip_distance']
    
    df[categorical] = df[categorical].astype(str)

    return df

# %%
# Receive the dataframe 
df_train = read_dataframe('data/green_tripdata_2021-01.parquet')
df_val   = read_dataframe('data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
# Create a new column 'PU_DO'
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
# Performs one-hot encoding of the categorical variables
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
# Extract the target variables
y_train = df_train['duration'].values
y_val   = df_val['duration'].values

# %%
# Defines and train the model
lr = LinearRegression()
lr.fit(X_train, y_train)

# Predictions
y_pred = lr.predict(X_train)
val_pred = lr.predict(X_val)

# Train metrics Calculation
train_rmse = mean_squared_error(y_train, y_pred, squared=False)
train_r2   = r2_score(y_train, y_pred)
    
# Validation metrics calculation
val_rmse = mean_squared_error(y_val, val_pred, squared=False)
val_r2   = r2_score(y_val, val_pred)
    

# Metrics printing
print('train mse score:',train_rmse)
print('train r2-score:', train_r2)
    
print('\nval_rmse: ', val_rmse)
print('\nval_r2: ', val_r2)
# Out:
# train mse score: 5.6995641181989765
# train r2-score: 0.7570393923885601
#
# val_rmse:  7.758715203341164
#
# val_r2:  0.5937204154722253

# %%
with open('model/linReg.bin', 'wb' ) as file:
    pickle.dump((dv, lr), file)

# %%
# Defining mlflow track-keeping
with mlflow.start_run():
    
    mlflow.set_tag("developer", 'Enoch')

    mlflow.log_param("train_data path", "data/green_tripdata_2021-01.parquet")
    mlflow.log_param("valid_data path", "data/green_tripdata_2021-02.parquet")
    
    alpha = 0.001
    mlflow.log_param('alpha', alpha)
    
    # with LASSO Regularization
    lr = Lasso(alpha=alpha)
    lr.fit(X_train, y_train)

    # Predictions
    y_pred = lr.predict(X_train)
    val_pred = lr.predict(X_val)

    # Train metrics Calculation
    train_rmse = mean_squared_error(y_train, y_pred, squared=False)
    train_r2   = r2_score(y_train, y_pred)
    
    # Validation metrics calculation
    val_rmse = mean_squared_error(y_val, val_pred, squared=False)
    val_r2   = r2_score(y_val, val_pred)
    
    # mlflow tracking
    mlflow.log_metric("train_rmse", train_rmse)
    mlflow.log_metric("train_r2-score", train_r2)
    mlflow.log_metric("valid_rmse", val_rmse)
    mlflow.log_metric("valid-r2", val_r2)


    # Metrics printing
    print('train mse score:',train_rmse)
    print('train r2-score:', train_r2)
    
    print('\nval_rmse: ', val_rmse)
    print('\nval_r2: ', val_r2)

    mlflow.log_artifact(local_path="model/lr1.bin", artifact_path="models_pickle")
# Out:
# train mse score: 8.345478908061276
# train r2-score: 0.4790991029135001
#
# val_rmse:  9.233436225720547
#
# val_r2:  0.4245970472706959

# %%
with mlflow.start_run():
    
    mlflow.set_tag("developer", 'Enoch')

    mlflow.log_param("train_data path", "data/green_tripdata_2021-01.parquet")
    mlflow.log_param("valid_data path", "data/green_tripdata_2021-02.parquet")
    
    alpha = 0.001
    mlflow.log_param('alpha', alpha)

    # with RIDGE Regularization
    lr = Ridge(alpha=alpha)
    lr.fit(X_train, y_train)

    # Predictions
    y_pred = lr.predict(X_train)
    val_pred = lr.predict(X_val)

    # Train metrics Calculation
    train_rmse = mean_squared_error(y_train, y_pred, squared=False)
    train_r2   = r2_score(y_train, y_pred)
    
    # Validation metrics calculation
    val_rmse = mean_squared_error(y_val, val_pred, squared=False)
    val_r2   = r2_score(y_val, val_pred)
    
    # mlflow tracking
    mlflow.log_metric("train_rmse", train_rmse)
    mlflow.log_metric("train_r2-score", train_r2)
    mlflow.log_metric("valid_rmse", val_rmse)
    mlflow.log_metric("valid-r2", val_r2)


    # Metrics printing
    print('train mse score:',train_rmse)
    print('train r2-score:', train_r2)
    
    print('\n val_rmse: ', val_rmse)
    print('\n val_r2: ', val_r2)

    mlflow.log_artifact(local_path="model/lr1.bin", artifact_path="models_pickle")
# Out:
# train mse score: 4.944550134760984
# train r2-score: 0.817145291823711
#
#  val_rmse:  7.510909603240781
#
#  val_r2:  0.6192582965973402

# %%
with open('model/lr1.bin', 'wb' ) as file:
    pickle.dump((dv, lr), file)

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    
    mlflow.xgboost.autolog()
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, "validation")],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha' : hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42,
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials())

# %%
 # Supposed these are the best model metrics
params = {
    'learning_rate': 0.20472169880371677,
    'max_depth': 17,
    'min_child_weight': 1.240261172,
    'objective': 'reg:linear',
    'reg_alpha': 0.28567896,
    'reg_lambda': 0.00426448,
    'seed': 42
}

mlflow

mlflow.xgboost.autolog()
booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, "validation")],
            early_stopping_rounds=50
        )
# Out:
# 2023/12/20 14:37:53 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'bf25fbfa672a4390b35aaa48b1437eb5', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [14:38:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:17.57670
# [1]	validation-rmse:14.77950
# [2]	validation-rmse:12.64199
# [3]	validation-rmse:11.02820
# [4]	validation-rmse:9.82436
# [5]	validation-rmse:8.93793
# [6]	validation-rmse:8.29597
# [7]	validation-rmse:7.82922
# [8]	validation-rmse:7.49422
# [9]	validation-rmse:7.25124
# [10]	validation-rmse:7.07616
# [11]	validation-rmse:6.94884
# [12]	validation-rmse:6.85678
# [13]	validation-rmse:6.78789
# [14]	validation-rmse:6.73514
# [15]	validation-rmse:6.69523
# [16]	validation-rmse:6.66330
# [17]	validation-rmse:6.64037
# [18]	validation-rmse:6.62226
# [19]	validation-rmse:6.60733
# [20]	validation-rmse:6.59614
# [21]	validation-rmse:6.58815
# [22]	validation-rmse:6.58247
# [23]	validation-rmse:6.57662
# [24]	validation-rmse:6.57243
# [25]	validation-rmse:6.56791
# [26]	validation-rmse:6.56230
# [27]	validation-rmse:6.55841
# [28]	validation-rmse:6.55557
# [29]	validation-rmse:6.55308
# [30]	validation-rmse:6.55027
# [31]	validation-rmse:6.54842
# [32]	validation-rmse:6.54676
# [33]	validation-rmse:6.54419
# [34]	validation-rmse:6.54081
# [35]	validation-rmse:6.53994
# [36]	validation-rmse:6.53743
# [37]	validation-rmse:6.53577
# [38]	validation-rmse:6.53425
# [39]	validation-rmse:6.53283
# [40]	validation-rmse:6.53172
# [41]	validation-rmse:6.53100
# [42]	validation-rmse:6.52960
# [43]	validation-rmse:6.52879
# [44]	validation-rmse:6.52725
# [45]	validation-rmse:6.52549
# [46]	validation-rmse:6.52398
# [47]	validation-rmse:6.52260
# [48]	validation-rmse:6.52147
# [49]	validation-rmse:6.51975
# [50]	validation-rmse:6.51835
# [51]	validation-rmse:6.51704
# [52]	validation-rmse:6.51571
# [53]	validation-rmse:6.51439
# [54]	validation-rmse:6.51332
# [55]	validation-rmse:6.51210
# [56]	validation-rmse:6.51104
# [57]	validation-rmse:6.50925
# [58]	validation-rmse:6.50804
# [59]	validation-rmse:6.50672
# [60]	validation-rmse:6.50567
# [61]	validation-rmse:6.50498
# [62]	validation-rmse:6.50456
# [63]	validation-rmse:6.50366
# [64]	validation-rmse:6.50267
# [65]	validation-rmse:6.50210
# [66]	validation-rmse:6.50117
# [67]	validation-rmse:6.49999
# [68]	validation-rmse:6.49931
# [69]	validation-rmse:6.49848
# [70]	validation-rmse:6.49780
# [71]	validation-rmse:6.49641
# [72]	validation-rmse:6.49567
# [73]	validation-rmse:6.49430
# [74]	validation-rmse:6.49195
# [75]	validation-rmse:6.49093
# [76]	validation-rmse:6.48952
# [77]	validation-rmse:6.48903
# [78]	validation-rmse:6.48856
# [79]	validation-rmse:6.48724
# [80]	validation-rmse:6.48600
# [81]	validation-rmse:6.48473
# [82]	validation-rmse:6.48394
# [83]	validation-rmse:6.48288
# [84]	validation-rmse:6.48184
# [85]	validation-rmse:6.48103
# [86]	validation-rmse:6.47995
# [87]	validation-rmse:6.47907
# [88]	validation-rmse:6.47796
# [89]	validation-rmse:6.47728
# [90]	validation-rmse:6.47669
# [91]	validation-rmse:6.47578
# [92]	validation-rmse:6.47531
# [93]	validation-rmse:6.47368
# [94]	validation-rmse:6.47206
# [95]	validation-rmse:6.47134
# [96]	validation-rmse:6.46970
# [97]	validation-rmse:6.46886
# [98]	validation-rmse:6.46876
# [99]	validation-rmse:6.46788
# [100]	validation-rmse:6.46735
# [101]	validation-rmse:6.46645
# [102]	validation-rmse:6.46570
# [103]	validation-rmse:6.46487
# [104]	validation-rmse:6.46434
# [105]	validation-rmse:6.46339
# [106]	validation-rmse:6.46244
# [107]	validation-rmse:6.46187
# [108]	validation-rmse:6.46122
# [109]	validation-rmse:6.46025
# [110]	validation-rmse:6.45972
# [111]	validation-rmse:6.45903
# [112]	validation-rmse:6.45828
# [113]	validation-rmse:6.45778
# [114]	validation-rmse:6.45675
# [115]	validation-rmse:6.45616
# [116]	validation-rmse:6.45550
# [117]	validation-rmse:6.45505
# [118]	validation-rmse:6.45456
# [119]	validation-rmse:6.45379
# [120]	validation-rmse:6.45323
# [121]	validation-rmse:6.45220
# [122]	validation-rmse:6.45145
# [123]	validation-rmse:6.45047
# [124]	validation-rmse:6.44971
# [125]	validation-rmse:6.44903
# [126]	validation-rmse:6.44865
# [127]	validation-rmse:6.44815
# [128]	validation-rmse:6.44734
# [129]	validation-rmse:6.44670
# [130]	validation-rmse:6.44630
# [131]	validation-rmse:6.44601
# [132]	validation-rmse:6.44582
# [133]	validation-rmse:6.44518
# [134]	validation-rmse:6.44437
# [135]	validation-rmse:6.44368
# [136]	validation-rmse:6.44351
# [137]	validation-rmse:6.44299
# [138]	validation-rmse:6.44251
# [139]	validation-rmse:6.44208
# [140]	validation-rmse:6.44178
# [141]	validation-rmse:6.44091
# [142]	validation-rmse:6.44049
# [143]	validation-rmse:6.43966
# [144]	validation-rmse:6.43918
# [145]	validation-rmse:6.43866
# [146]	validation-rmse:6.43819
# [147]	validation-rmse:6.43773
# [148]	validation-rmse:6.43686
# [149]	validation-rmse:6.43619
# [150]	validation-rmse:6.43555
# [151]	validation-rmse:6.43529
# [152]	validation-rmse:6.43484
# [153]	validation-rmse:6.43369
# [154]	validation-rmse:6.43359
# [155]	validation-rmse:6.43265
# [156]	validation-rmse:6.43220
# [157]	validation-rmse:6.43217
# [158]	validation-rmse:6.43201
# [159]	validation-rmse:6.43141
# [160]	validation-rmse:6.43124
# [161]	validation-rmse:6.43064
# [162]	validation-rmse:6.43014
# [163]	validation-rmse:6.42955
# [164]	validation-rmse:6.42899
# [165]	validation-rmse:6.42874
# [166]	validation-rmse:6.42743
# [167]	validation-rmse:6.42643
# [168]	validation-rmse:6.42640
# [169]	validation-rmse:6.42595
# [170]	validation-rmse:6.42529
# [171]	validation-rmse:6.42493
# [172]	validation-rmse:6.42397
# [173]	validation-rmse:6.42359
# [174]	validation-rmse:6.42260
# [175]	validation-rmse:6.42188
# [176]	validation-rmse:6.42144
# [177]	validation-rmse:6.42093
# [178]	validation-rmse:6.41995
# [179]	validation-rmse:6.41965
# [180]	validation-rmse:6.41914
# [181]	validation-rmse:6.41803
# [182]	validation-rmse:6.41720
# [183]	validation-rmse:6.41713
# [184]	validation-rmse:6.41688
# [185]	validation-rmse:6.41663
# [186]	validation-rmse:6.41598
# [187]	validation-rmse:6.41516
# [188]	validation-rmse:6.41472
# [189]	validation-rmse:6.41402
# [190]	validation-rmse:6.41323
# [191]	validation-rmse:6.41269
# [192]	validation-rmse:6.41208
# [193]	validation-rmse:6.41152
# [194]	validation-rmse:6.41116
# [195]	validation-rmse:6.41069
# [196]	validation-rmse:6.41036
# [197]	validation-rmse:6.40985
# [198]	validation-rmse:6.40952
# [199]	validation-rmse:6.40916
# [200]	validation-rmse:6.40829
# [201]	validation-rmse:6.40784
# [202]	validation-rmse:6.40743
# [203]	validation-rmse:6.40704
# [204]	validation-rmse:6.40664
# [205]	validation-rmse:6.40601
# [206]	validation-rmse:6.40565
# [207]	validation-rmse:6.40521
# [208]	validation-rmse:6.40467
# [209]	validation-rmse:6.40391
# [210]	validation-rmse:6.40358
# [211]	validation-rmse:6.40314
# [212]	validation-rmse:6.40267
# [213]	validation-rmse:6.40221
# [214]	validation-rmse:6.40175
# [215]	validation-rmse:6.40084
# [216]	validation-rmse:6.40017
# [217]	validation-rmse:6.40012
# [218]	validation-rmse:6.39961
# [219]	validation-rmse:6.39926
# [220]	validation-rmse:6.39888
# [221]	validation-rmse:6.39867
# [222]	validation-rmse:6.39821
# [223]	validation-rmse:6.39754
# [224]	validation-rmse:6.39729
# [225]	validation-rmse:6.39653
# [226]	validation-rmse:6.39557
# [227]	validation-rmse:6.39535
# [228]	validation-rmse:6.39510
# [229]	validation-rmse:6.39459
# [230]	validation-rmse:6.39401
# [231]	validation-rmse:6.39387
# [232]	validation-rmse:6.39335
# [233]	validation-rmse:6.39301
# [234]	validation-rmse:6.39259
# [235]	validation-rmse:6.39230
# [236]	validation-rmse:6.39154
# [237]	validation-rmse:6.39124
# [238]	validation-rmse:6.39078
# [239]	validation-rmse:6.39040
# [240]	validation-rmse:6.39014
# [241]	validation-rmse:6.38974
# [242]	validation-rmse:6.38963
# [243]	validation-rmse:6.38913
# [244]	validation-rmse:6.38930
# [245]	validation-rmse:6.38925
# [246]	validation-rmse:6.38923
# [247]	validation-rmse:6.38915
# [248]	validation-rmse:6.38891
# [249]	validation-rmse:6.38839
# [250]	validation-rmse:6.38781
# [251]	validation-rmse:6.38779
# [252]	validation-rmse:6.38761
# [253]	validation-rmse:6.38738
# [254]	validation-rmse:6.38739
# [255]	validation-rmse:6.38718
# [256]	validation-rmse:6.38710
# [257]	validation-rmse:6.38665
# [258]	validation-rmse:6.38614
# [259]	validation-rmse:6.38575
# [260]	validation-rmse:6.38563
# [261]	validation-rmse:6.38544
# [262]	validation-rmse:6.38520
# [263]	validation-rmse:6.38509
# [264]	validation-rmse:6.38447
# [265]	validation-rmse:6.38447
# [266]	validation-rmse:6.38421
# [267]	validation-rmse:6.38377
# [268]	validation-rmse:6.38335
# [269]	validation-rmse:6.38319
# [270]	validation-rmse:6.38279
# [271]	validation-rmse:6.38246
# [272]	validation-rmse:6.38209
# [273]	validation-rmse:6.38178
# [274]	validation-rmse:6.38122
# [275]	validation-rmse:6.38084
# [276]	validation-rmse:6.38059
# [277]	validation-rmse:6.38039
# [278]	validation-rmse:6.38016
# [279]	validation-rmse:6.38023
# [280]	validation-rmse:6.37994
# [281]	validation-rmse:6.37964
# [282]	validation-rmse:6.37934
# [283]	validation-rmse:6.37903
# [284]	validation-rmse:6.37857
# [285]	validation-rmse:6.37822
# [286]	validation-rmse:6.37776
# [287]	validation-rmse:6.37748
# [288]	validation-rmse:6.37711
# [289]	validation-rmse:6.37686
# [290]	validation-rmse:6.37656
# [291]	validation-rmse:6.37631
# [292]	validation-rmse:6.37595
# [293]	validation-rmse:6.37548
# [294]	validation-rmse:6.37526
# [295]	validation-rmse:6.37487
# [296]	validation-rmse:6.37458
# [297]	validation-rmse:6.37408
# [298]	validation-rmse:6.37377
# [299]	validation-rmse:6.37325
# [300]	validation-rmse:6.37320
# [301]	validation-rmse:6.37295
# [302]	validation-rmse:6.37202
# [303]	validation-rmse:6.37178
# [304]	validation-rmse:6.37134
# [305]	validation-rmse:6.37106
# [306]	validation-rmse:6.37081
# [307]	validation-rmse:6.37047
# [308]	validation-rmse:6.37004
# [309]	validation-rmse:6.36980
# [310]	validation-rmse:6.36954
# [311]	validation-rmse:6.36924
# [312]	validation-rmse:6.36906
# [313]	validation-rmse:6.36883
# [314]	validation-rmse:6.36848
# [315]	validation-rmse:6.36844
# [316]	validation-rmse:6.36806
# [317]	validation-rmse:6.36777
# [318]	validation-rmse:6.36720
# [319]	validation-rmse:6.36690
# [320]	validation-rmse:6.36667
# [321]	validation-rmse:6.36659
# [322]	validation-rmse:6.36645
# [323]	validation-rmse:6.36612
# [324]	validation-rmse:6.36529
# [325]	validation-rmse:6.36474
# [326]	validation-rmse:6.36467
# [327]	validation-rmse:6.36410
# [328]	validation-rmse:6.36392
# [329]	validation-rmse:6.36333
# [330]	validation-rmse:6.36318
# [331]	validation-rmse:6.36284
# [332]	validation-rmse:6.36275
# [333]	validation-rmse:6.36247
# [334]	validation-rmse:6.36219
# [335]	validation-rmse:6.36195
# [336]	validation-rmse:6.36138
# [337]	validation-rmse:6.36109
# [338]	validation-rmse:6.36102
# [339]	validation-rmse:6.36073
# [340]	validation-rmse:6.36049
# [341]	validation-rmse:6.36007
# [342]	validation-rmse:6.35995
# [343]	validation-rmse:6.35973
# [344]	validation-rmse:6.35916
# [345]	validation-rmse:6.35896
# [346]	validation-rmse:6.35875
# [347]	validation-rmse:6.35800
# [348]	validation-rmse:6.35785
# [349]	validation-rmse:6.35735
# [350]	validation-rmse:6.35667
# [351]	validation-rmse:6.35667
# [352]	validation-rmse:6.35628
# [353]	validation-rmse:6.35566
# [354]	validation-rmse:6.35555
# [355]	validation-rmse:6.35522
# [356]	validation-rmse:6.35506
# [357]	validation-rmse:6.35485
# [358]	validation-rmse:6.35451
# [359]	validation-rmse:6.35448
# [360]	validation-rmse:6.35421
# [361]	validation-rmse:6.35396
# [362]	validation-rmse:6.35400
# [363]	validation-rmse:6.35374
# [364]	validation-rmse:6.35349
# [365]	validation-rmse:6.35348
# [366]	validation-rmse:6.35324
# [367]	validation-rmse:6.35296
# [368]	validation-rmse:6.35260
# [369]	validation-rmse:6.35229
# [370]	validation-rmse:6.35219
# [371]	validation-rmse:6.35197
# [372]	validation-rmse:6.35186
# [373]	validation-rmse:6.35150
# [374]	validation-rmse:6.35127
# [375]	validation-rmse:6.35101
# [376]	validation-rmse:6.35096
# [377]	validation-rmse:6.34993
# [378]	validation-rmse:6.34992
# [379]	validation-rmse:6.34974
# [380]	validation-rmse:6.34921
# [381]	validation-rmse:6.34901
# [382]	validation-rmse:6.34878
# [383]	validation-rmse:6.34855
# [384]	validation-rmse:6.34824
# [385]	validation-rmse:6.34802
# [386]	validation-rmse:6.34780
# [387]	validation-rmse:6.34763
# [388]	validation-rmse:6.34741
# [389]	validation-rmse:6.34711
# [390]	validation-rmse:6.34689
# [391]	validation-rmse:6.34675
# [392]	validation-rmse:6.34688
# [393]	validation-rmse:6.34661
# [394]	validation-rmse:6.34610
# [395]	validation-rmse:6.34590
# [396]	validation-rmse:6.34567
# [397]	validation-rmse:6.34555
# [398]	validation-rmse:6.34535
# [399]	validation-rmse:6.34551
# [400]	validation-rmse:6.34547
# [401]	validation-rmse:6.34525
# [402]	validation-rmse:6.34473
# [403]	validation-rmse:6.34447
# [404]	validation-rmse:6.34478
# [405]	validation-rmse:6.34462
# [406]	validation-rmse:6.34468
# [407]	validation-rmse:6.34445
# [408]	validation-rmse:6.34437
# [409]	validation-rmse:6.34401
# [410]	validation-rmse:6.34372
# [411]	validation-rmse:6.34355
# [412]	validation-rmse:6.34358
# [413]	validation-rmse:6.34346
# [414]	validation-rmse:6.34314
# [415]	validation-rmse:6.34318
# [416]	validation-rmse:6.34285
# [417]	validation-rmse:6.34293
# [418]	validation-rmse:6.34280
# [419]	validation-rmse:6.34253
# [420]	validation-rmse:6.34223
# [421]	validation-rmse:6.34167
# [422]	validation-rmse:6.34137
# [423]	validation-rmse:6.34129
# [424]	validation-rmse:6.34113
# [425]	validation-rmse:6.34115
# [426]	validation-rmse:6.34097
# [427]	validation-rmse:6.34091
# [428]	validation-rmse:6.34082
# [429]	validation-rmse:6.34059
# [430]	validation-rmse:6.34033
# [431]	validation-rmse:6.33958
# [432]	validation-rmse:6.33964
# [433]	validation-rmse:6.33978
# [434]	validation-rmse:6.33969
# [435]	validation-rmse:6.33944
# [436]	validation-rmse:6.33906
# [437]	validation-rmse:6.33892
# [438]	validation-rmse:6.33886
# [439]	validation-rmse:6.33870
# [440]	validation-rmse:6.33845
# [441]	validation-rmse:6.33827
# [442]	validation-rmse:6.33804
# [443]	validation-rmse:6.33776
# [444]	validation-rmse:6.33739
# [445]	validation-rmse:6.33718
# [446]	validation-rmse:6.33722
# [447]	validation-rmse:6.33718
# [448]	validation-rmse:6.33726
# [449]	validation-rmse:6.33690
# [450]	validation-rmse:6.33737
# [451]	validation-rmse:6.33721
# [452]	validation-rmse:6.33714
# [453]	validation-rmse:6.33668
# [454]	validation-rmse:6.33655
# [455]	validation-rmse:6.33638
# [456]	validation-rmse:6.33624
# [457]	validation-rmse:6.33626
# [458]	validation-rmse:6.33610
# [459]	validation-rmse:6.33602
# [460]	validation-rmse:6.33595
# [461]	validation-rmse:6.33597
# [462]	validation-rmse:6.33572
# [463]	validation-rmse:6.33538
# [464]	validation-rmse:6.33479
# [465]	validation-rmse:6.33464
# [466]	validation-rmse:6.33437
# [467]	validation-rmse:6.33427
# [468]	validation-rmse:6.33409
# [469]	validation-rmse:6.33403
# [470]	validation-rmse:6.33395
# [471]	validation-rmse:6.33364
# [472]	validation-rmse:6.33346
# [473]	validation-rmse:6.33306
# [474]	validation-rmse:6.33311
# [475]	validation-rmse:6.33299
# [476]	validation-rmse:6.33267
# [477]	validation-rmse:6.33241
# [478]	validation-rmse:6.33235
# [479]	validation-rmse:6.33246
# [480]	validation-rmse:6.33221
# [481]	validation-rmse:6.33229
# [482]	validation-rmse:6.33216
# [483]	validation-rmse:6.33221
# [484]	validation-rmse:6.33222
# [485]	validation-rmse:6.33198
# [486]	validation-rmse:6.33198
# [487]	validation-rmse:6.33169
# [488]	validation-rmse:6.33156
# [489]	validation-rmse:6.33155
# [490]	validation-rmse:6.33147
# [491]	validation-rmse:6.33132
# [492]	validation-rmse:6.33135
# [493]	validation-rmse:6.33105
# [494]	validation-rmse:6.33086
# [495]	validation-rmse:6.33042
# [496]	validation-rmse:6.33010
# [497]	validation-rmse:6.33012
# [498]	validation-rmse:6.32995
# [499]	validation-rmse:6.32968
# [500]	validation-rmse:6.32917
# [501]	validation-rmse:6.32884
# [502]	validation-rmse:6.32869
# [503]	validation-rmse:6.32847
# [504]	validation-rmse:6.32819
# [505]	validation-rmse:6.32785
# [506]	validation-rmse:6.32768
# [507]	validation-rmse:6.32730
# [508]	validation-rmse:6.32726
# [509]	validation-rmse:6.32722
# [510]	validation-rmse:6.32700
# [511]	validation-rmse:6.32695
# [512]	validation-rmse:6.32694
# [513]	validation-rmse:6.32667
# [514]	validation-rmse:6.32674
# [515]	validation-rmse:6.32664
# [516]	validation-rmse:6.32667
# [517]	validation-rmse:6.32661
# [518]	validation-rmse:6.32684
# [519]	validation-rmse:6.32690
# [520]	validation-rmse:6.32643
# [521]	validation-rmse:6.32610
# [522]	validation-rmse:6.32589
# [523]	validation-rmse:6.32578
# [524]	validation-rmse:6.32536
# [525]	validation-rmse:6.32492
# [526]	validation-rmse:6.32495
# [527]	validation-rmse:6.32454
# [528]	validation-rmse:6.32446
# [529]	validation-rmse:6.32425
# [530]	validation-rmse:6.32395
# [531]	validation-rmse:6.32375
# [532]	validation-rmse:6.32356
# [533]	validation-rmse:6.32361
# [534]	validation-rmse:6.32355
# [535]	validation-rmse:6.32358
# [536]	validation-rmse:6.32327
# [537]	validation-rmse:6.32325
# [538]	validation-rmse:6.32281
# [539]	validation-rmse:6.32270
# [540]	validation-rmse:6.32253
# [541]	validation-rmse:6.32247
# [542]	validation-rmse:6.32251
# [543]	validation-rmse:6.32267
# [544]	validation-rmse:6.32246
# [545]	validation-rmse:6.32220
# [546]	validation-rmse:6.32221
# [547]	validation-rmse:6.32213
# [548]	validation-rmse:6.32210
# [549]	validation-rmse:6.32200
# [550]	validation-rmse:6.32178
# [551]	validation-rmse:6.32168
# [552]	validation-rmse:6.32171
# [553]	validation-rmse:6.32151
# [554]	validation-rmse:6.32140
# [555]	validation-rmse:6.32150
# [556]	validation-rmse:6.32131
# [557]	validation-rmse:6.32121
# [558]	validation-rmse:6.32085
# [559]	validation-rmse:6.32081
# [560]	validation-rmse:6.32076
# [561]	validation-rmse:6.32059
# [562]	validation-rmse:6.32040
# [563]	validation-rmse:6.32041
# [564]	validation-rmse:6.32021
# [565]	validation-rmse:6.32015
# [566]	validation-rmse:6.32021
# [567]	validation-rmse:6.32015
# [568]	validation-rmse:6.31988
# [569]	validation-rmse:6.31971
# [570]	validation-rmse:6.31967
# [571]	validation-rmse:6.31940
# [572]	validation-rmse:6.31968
# [573]	validation-rmse:6.31961
# [574]	validation-rmse:6.31959
# [575]	validation-rmse:6.31945
# [576]	validation-rmse:6.31906
# [577]	validation-rmse:6.31904
# [578]	validation-rmse:6.31892
# [579]	validation-rmse:6.31883
# [580]	validation-rmse:6.31863
# [581]	validation-rmse:6.31856
# [582]	validation-rmse:6.31862
# [583]	validation-rmse:6.31846
# [584]	validation-rmse:6.31836
# [585]	validation-rmse:6.31813
# [586]	validation-rmse:6.31781
# [587]	validation-rmse:6.31765
# [588]	validation-rmse:6.31752
# [589]	validation-rmse:6.31760
# [590]	validation-rmse:6.31747
# [591]	validation-rmse:6.31712
# [592]	validation-rmse:6.31691
# [593]	validation-rmse:6.31671
# [594]	validation-rmse:6.31663
# [595]	validation-rmse:6.31650
# [596]	validation-rmse:6.31645
# [597]	validation-rmse:6.31640
# [598]	validation-rmse:6.31623
# [599]	validation-rmse:6.31627
# [600]	validation-rmse:6.31611
# [601]	validation-rmse:6.31590
# [602]	validation-rmse:6.31597
# [603]	validation-rmse:6.31573
# [604]	validation-rmse:6.31561
# [605]	validation-rmse:6.31553
# [606]	validation-rmse:6.31576
# [607]	validation-rmse:6.31560
# [608]	validation-rmse:6.31540
# [609]	validation-rmse:6.31543
# [610]	validation-rmse:6.31548
# [611]	validation-rmse:6.31536
# [612]	validation-rmse:6.31527
# [613]	validation-rmse:6.31528
# [614]	validation-rmse:6.31503
# [615]	validation-rmse:6.31505
# [616]	validation-rmse:6.31498
# [617]	validation-rmse:6.31503
# [618]	validation-rmse:6.31471
# [619]	validation-rmse:6.31481
# [620]	validation-rmse:6.31455
# [621]	validation-rmse:6.31434
# [622]	validation-rmse:6.31448
# [623]	validation-rmse:6.31423
# [624]	validation-rmse:6.31405
# [625]	validation-rmse:6.31439
# [626]	validation-rmse:6.31428
# [627]	validation-rmse:6.31353
# [628]	validation-rmse:6.31333
# [629]	validation-rmse:6.31314
# [630]	validation-rmse:6.31323
# [631]	validation-rmse:6.31338
# [632]	validation-rmse:6.31328
# [633]	validation-rmse:6.31333
# [634]	validation-rmse:6.31334
# [635]	validation-rmse:6.31308
# [636]	validation-rmse:6.31298
# [637]	validation-rmse:6.31295
# [638]	validation-rmse:6.31306
# [639]	validation-rmse:6.31307
# [640]	validation-rmse:6.31294
# [641]	validation-rmse:6.31292
# [642]	validation-rmse:6.31270
# [643]	validation-rmse:6.31269
# [644]	validation-rmse:6.31257
# [645]	validation-rmse:6.31241
# [646]	validation-rmse:6.31227
# [647]	validation-rmse:6.31220
# [648]	validation-rmse:6.31219
# [649]	validation-rmse:6.31249
# [650]	validation-rmse:6.31238
# [651]	validation-rmse:6.31236
# [652]	validation-rmse:6.31212
# [653]	validation-rmse:6.31186
# [654]	validation-rmse:6.31175
# [655]	validation-rmse:6.31189
# [656]	validation-rmse:6.31200
# [657]	validation-rmse:6.31178
# [658]	validation-rmse:6.31141
# [659]	validation-rmse:6.31114
# [660]	validation-rmse:6.31093
# [661]	validation-rmse:6.31048
# [662]	validation-rmse:6.31043
# [663]	validation-rmse:6.31014
# [664]	validation-rmse:6.31021
# [665]	validation-rmse:6.30990
# [666]	validation-rmse:6.30993
# [667]	validation-rmse:6.31002
# [668]	validation-rmse:6.30993
# [669]	validation-rmse:6.30975
# [670]	validation-rmse:6.30970
# [671]	validation-rmse:6.30958
# [672]	validation-rmse:6.30952
# [673]	validation-rmse:6.30928
# [674]	validation-rmse:6.30911
# [675]	validation-rmse:6.30925
# [676]	validation-rmse:6.30892
# [677]	validation-rmse:6.30894
# [678]	validation-rmse:6.30896
# [679]	validation-rmse:6.30877
# [680]	validation-rmse:6.30869
# [681]	validation-rmse:6.30864
# [682]	validation-rmse:6.30871
# [683]	validation-rmse:6.30866
# [684]	validation-rmse:6.30911
# [685]	validation-rmse:6.30893
# [686]	validation-rmse:6.30900
# [687]	validation-rmse:6.30914
# [688]	validation-rmse:6.30883
# [689]	validation-rmse:6.30873
# [690]	validation-rmse:6.30859
# [691]	validation-rmse:6.30853
# [692]	validation-rmse:6.30854
# [693]	validation-rmse:6.30845
# [694]	validation-rmse:6.30834
# [695]	validation-rmse:6.30848
# [696]	validation-rmse:6.30820
# [697]	validation-rmse:6.30818
# [698]	validation-rmse:6.30790
# [699]	validation-rmse:6.30786
# [700]	validation-rmse:6.30781
# [701]	validation-rmse:6.30787
# [702]	validation-rmse:6.30792
# [703]	validation-rmse:6.30785
# [704]	validation-rmse:6.30774
# [705]	validation-rmse:6.30767
# [706]	validation-rmse:6.30761
# [707]	validation-rmse:6.30754
# [708]	validation-rmse:6.30740
# [709]	validation-rmse:6.30720
# [710]	validation-rmse:6.30693
# [711]	validation-rmse:6.30689
# [712]	validation-rmse:6.30675
# [713]	validation-rmse:6.30666
# [714]	validation-rmse:6.30667
# [715]	validation-rmse:6.30657
# [716]	validation-rmse:6.30670
# [717]	validation-rmse:6.30640
# [718]	validation-rmse:6.30595
# [719]	validation-rmse:6.30598
# [720]	validation-rmse:6.30607
# [721]	validation-rmse:6.30617
# [722]	validation-rmse:6.30618
# [723]	validation-rmse:6.30611
# [724]	validation-rmse:6.30612
# [725]	validation-rmse:6.30610
# [726]	validation-rmse:6.30624
# [727]	validation-rmse:6.30607
# [728]	validation-rmse:6.30600
# [729]	validation-rmse:6.30584
# [730]	validation-rmse:6.30553
# [731]	validation-rmse:6.30542
# [732]	validation-rmse:6.30521
# [733]	validation-rmse:6.30508
# [734]	validation-rmse:6.30498
# [735]	validation-rmse:6.30498
# [736]	validation-rmse:6.30499
# [737]	validation-rmse:6.30484
# [738]	validation-rmse:6.30453
# [739]	validation-rmse:6.30449
# [740]	validation-rmse:6.30440
# [741]	validation-rmse:6.30440
# [742]	validation-rmse:6.30422
# [743]	validation-rmse:6.30452
# [744]	validation-rmse:6.30449
# [745]	validation-rmse:6.30446
# [746]	validation-rmse:6.30438
# [747]	validation-rmse:6.30418
# [748]	validation-rmse:6.30413
# [749]	validation-rmse:6.30394
# [750]	validation-rmse:6.30391
# [751]	validation-rmse:6.30376
# [752]	validation-rmse:6.30352
# [753]	validation-rmse:6.30337
# [754]	validation-rmse:6.30318
# [755]	validation-rmse:6.30321
# [756]	validation-rmse:6.30332
# [757]	validation-rmse:6.30321
# [758]	validation-rmse:6.30310
# [759]	validation-rmse:6.30295
# [760]	validation-rmse:6.30281
# [761]	validation-rmse:6.30254
# [762]	validation-rmse:6.30265
# [763]	validation-rmse:6.30239
# [764]	validation-rmse:6.30234
# [765]	validation-rmse:6.30235
# [766]	validation-rmse:6.30226
# [767]	validation-rmse:6.30222
# [768]	validation-rmse:6.30212
# [769]	validation-rmse:6.30204
# [770]	validation-rmse:6.30221
# [771]	validation-rmse:6.30245
# [772]	validation-rmse:6.30239
# [773]	validation-rmse:6.30228
# [774]	validation-rmse:6.30229
# [775]	validation-rmse:6.30221
# [776]	validation-rmse:6.30232
# [777]	validation-rmse:6.30240
# [778]	validation-rmse:6.30241
# [779]	validation-rmse:6.30236
# [780]	validation-rmse:6.30234
# [781]	validation-rmse:6.30241
# [782]	validation-rmse:6.30217
# [783]	validation-rmse:6.30161
# [784]	validation-rmse:6.30150
# [785]	validation-rmse:6.30154
# [786]	validation-rmse:6.30133
# [787]	validation-rmse:6.30152
# [788]	validation-rmse:6.30146
# [789]	validation-rmse:6.30138
# [790]	validation-rmse:6.30107
# [791]	validation-rmse:6.30087
# [792]	validation-rmse:6.30073
# [793]	validation-rmse:6.30054
# [794]	validation-rmse:6.30020
# [795]	validation-rmse:6.30001
# [796]	validation-rmse:6.30001
# [797]	validation-rmse:6.29989
# [798]	validation-rmse:6.29986
# [799]	validation-rmse:6.29979
# [800]	validation-rmse:6.29973
# [801]	validation-rmse:6.29953
# [802]	validation-rmse:6.29939
# [803]	validation-rmse:6.29925
# [804]	validation-rmse:6.29862
# [805]	validation-rmse:6.29860
# [806]	validation-rmse:6.29859
# [807]	validation-rmse:6.29852
# [808]	validation-rmse:6.29847
# [809]	validation-rmse:6.29849
# [810]	validation-rmse:6.29849
# [811]	validation-rmse:6.29856
# [812]	validation-rmse:6.29860
# [813]	validation-rmse:6.29853
# [814]	validation-rmse:6.29856
# [815]	validation-rmse:6.29786
# [816]	validation-rmse:6.29768
# [817]	validation-rmse:6.29761
# [818]	validation-rmse:6.29764
# [819]	validation-rmse:6.29746
# [820]	validation-rmse:6.29725
# [821]	validation-rmse:6.29778
# [822]	validation-rmse:6.29784
# [823]	validation-rmse:6.29783
# [824]	validation-rmse:6.29783
# [825]	validation-rmse:6.29775
# [826]	validation-rmse:6.29767
# [827]	validation-rmse:6.29755
# [828]	validation-rmse:6.29741
# [829]	validation-rmse:6.29742
# [830]	validation-rmse:6.29746
# [831]	validation-rmse:6.29721
# [832]	validation-rmse:6.29706
# [833]	validation-rmse:6.29712
# [834]	validation-rmse:6.29718
# [835]	validation-rmse:6.29718
# [836]	validation-rmse:6.29719
# [837]	validation-rmse:6.29734
# [838]	validation-rmse:6.29723
# [839]	validation-rmse:6.29720
# [840]	validation-rmse:6.29716
# [841]	validation-rmse:6.29714
# [842]	validation-rmse:6.29726
# [843]	validation-rmse:6.29709
# [844]	validation-rmse:6.29720
# [845]	validation-rmse:6.29713
# [846]	validation-rmse:6.29740
# [847]	validation-rmse:6.29733
# [848]	validation-rmse:6.29744
# [849]	validation-rmse:6.29749
# [850]	validation-rmse:6.29758
# [851]	validation-rmse:6.29748
# [852]	validation-rmse:6.29714
# [853]	validation-rmse:6.29714
# [854]	validation-rmse:6.29706
# [855]	validation-rmse:6.29706
# [856]	validation-rmse:6.29663
# [857]	validation-rmse:6.29660
# [858]	validation-rmse:6.29655
# [859]	validation-rmse:6.29643
# [860]	validation-rmse:6.29644
# [861]	validation-rmse:6.29637
# [862]	validation-rmse:6.29623
# [863]	validation-rmse:6.29625
# [864]	validation-rmse:6.29622
# [865]	validation-rmse:6.29603
# [866]	validation-rmse:6.29599
# [867]	validation-rmse:6.29584
# [868]	validation-rmse:6.29588
# [869]	validation-rmse:6.29600
# [870]	validation-rmse:6.29606
# [871]	validation-rmse:6.29595
# [872]	validation-rmse:6.29594
# [873]	validation-rmse:6.29591
# [874]	validation-rmse:6.29585
# [875]	validation-rmse:6.29584
# [876]	validation-rmse:6.29570
# [877]	validation-rmse:6.29576
# [878]	validation-rmse:6.29585
# [879]	validation-rmse:6.29594
# [880]	validation-rmse:6.29578
# [881]	validation-rmse:6.29581
# [882]	validation-rmse:6.29536
# [883]	validation-rmse:6.29545
# [884]	validation-rmse:6.29541
# [885]	validation-rmse:6.29534
# [886]	validation-rmse:6.29532
# [887]	validation-rmse:6.29531
# [888]	validation-rmse:6.29501
# [889]	validation-rmse:6.29501
# [890]	validation-rmse:6.29482
# [891]	validation-rmse:6.29471
# [892]	validation-rmse:6.29469
# [893]	validation-rmse:6.29474
# [894]	validation-rmse:6.29462
# [895]	validation-rmse:6.29454
# [896]	validation-rmse:6.29457
# [897]	validation-rmse:6.29450
# [898]	validation-rmse:6.29462
# [899]	validation-rmse:6.29458
# [900]	validation-rmse:6.29456
# [901]	validation-rmse:6.29458
# [902]	validation-rmse:6.29453
# [903]	validation-rmse:6.29459
# [904]	validation-rmse:6.29445
# [905]	validation-rmse:6.29430
# [906]	validation-rmse:6.29451
# [907]	validation-rmse:6.29458
# [908]	validation-rmse:6.29395
# [909]	validation-rmse:6.29400
# [910]	validation-rmse:6.29408
# [911]	validation-rmse:6.29467
# [912]	validation-rmse:6.29459
# [913]	validation-rmse:6.29459
# [914]	validation-rmse:6.29472
# [915]	validation-rmse:6.29478
# [916]	validation-rmse:6.29474
# [917]	validation-rmse:6.29466
# [918]	validation-rmse:6.29462
# [919]	validation-rmse:6.29468
# [920]	validation-rmse:6.29471
# [921]	validation-rmse:6.29460
# [922]	validation-rmse:6.29474
# [923]	validation-rmse:6.29451
# [924]	validation-rmse:6.29438
# [925]	validation-rmse:6.29450
# [926]	validation-rmse:6.29428
# [927]	validation-rmse:6.29422
# [928]	validation-rmse:6.29402
# [929]	validation-rmse:6.29394
# [930]	validation-rmse:6.29385
# [931]	validation-rmse:6.29369
# [932]	validation-rmse:6.29357
# [933]	validation-rmse:6.29381
# [934]	validation-rmse:6.29387
# [935]	validation-rmse:6.29358
# [936]	validation-rmse:6.29365
# [937]	validation-rmse:6.29373
# [938]	validation-rmse:6.29372
# [939]	validation-rmse:6.29367
# [940]	validation-rmse:6.29358
# [941]	validation-rmse:6.29364
# [942]	validation-rmse:6.29364
# [943]	validation-rmse:6.29368
# [944]	validation-rmse:6.29349
# [945]	validation-rmse:6.29362
# [946]	validation-rmse:6.29369
# [947]	validation-rmse:6.29379
# [948]	validation-rmse:6.29385
# [949]	validation-rmse:6.29365
# [950]	validation-rmse:6.29369
# [951]	validation-rmse:6.29355
# [952]	validation-rmse:6.29353
# [953]	validation-rmse:6.29336
# [954]	validation-rmse:6.29328
# [955]	validation-rmse:6.29332
# [956]	validation-rmse:6.29326
# [957]	validation-rmse:6.29312
# [958]	validation-rmse:6.29314
# [959]	validation-rmse:6.29274
# [960]	validation-rmse:6.29280
# [961]	validation-rmse:6.29288
# [962]	validation-rmse:6.29293
# [963]	validation-rmse:6.29286
# [964]	validation-rmse:6.29279
# [965]	validation-rmse:6.29292
# [966]	validation-rmse:6.29297
# [967]	validation-rmse:6.29266
# [968]	validation-rmse:6.29172
# [969]	validation-rmse:6.29178
# [970]	validation-rmse:6.29185
# [971]	validation-rmse:6.29185
# [972]	validation-rmse:6.29200
# [973]	validation-rmse:6.29173
# [974]	validation-rmse:6.29141
# [975]	validation-rmse:6.29130
# [976]	validation-rmse:6.29129
# [977]	validation-rmse:6.29121
# [978]	validation-rmse:6.29114
# [979]	validation-rmse:6.29117
# [980]	validation-rmse:6.29122
# [981]	validation-rmse:6.29129
# [982]	validation-rmse:6.29133
# [983]	validation-rmse:6.29133
# [984]	validation-rmse:6.29129
# [985]	validation-rmse:6.29128
# [986]	validation-rmse:6.29150
# [987]	validation-rmse:6.29155
# [988]	validation-rmse:6.29151
# [989]	validation-rmse:6.29151
# [990]	validation-rmse:6.29153
# [991]	validation-rmse:6.29151
# [992]	validation-rmse:6.29143
# [993]	validation-rmse:6.29123
# [994]	validation-rmse:6.29124
# [995]	validation-rmse:6.29116
# [996]	validation-rmse:6.29103
# [997]	validation-rmse:6.29098
# [998]	validation-rmse:6.29093
# [999]	validation-rmse:6.29096
# 2023/12/20 14:41:31 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.

# %%
mlflow.xgboost.autolog(disable=True)
# Model Management

# %%
with mlflow.start_run():
    best_params = {
    'learning_rate': 0.20472169880371677,
    'max_depth': 17,
    'min_child_weight': 1.240261172,
    'objective': 'reg:linear',
    'reg_alpha': 0.28567896,
    'reg_lambda': 0.00426448,
    'seed': 42
    }

    mlflow.log_params(best_params)
    
    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("model/preprocessor.b", 'wb') as f_out:
        pickle.dump(dv, f_out)

    mlflow.log_artifact("model/preprocessor.b", artifact_path='preprocessor')

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [15:06:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:17.57670
# [1]	validation-rmse:14.77950
# [2]	validation-rmse:12.64199
# [3]	validation-rmse:11.02820
# [4]	validation-rmse:9.82436
# [5]	validation-rmse:8.93793
# [6]	validation-rmse:8.29597
# [7]	validation-rmse:7.82922
# [8]	validation-rmse:7.49422
# [9]	validation-rmse:7.25124
# [10]	validation-rmse:7.07616
# [11]	validation-rmse:6.94884
# [12]	validation-rmse:6.85678
# [13]	validation-rmse:6.78789
# [14]	validation-rmse:6.73514
# [15]	validation-rmse:6.69523
# [16]	validation-rmse:6.66330
# [17]	validation-rmse:6.64037
# [18]	validation-rmse:6.62226
# [19]	validation-rmse:6.60733
# [20]	validation-rmse:6.59614
# [21]	validation-rmse:6.58815
# [22]	validation-rmse:6.58247
# [23]	validation-rmse:6.57662
# [24]	validation-rmse:6.57243
# [25]	validation-rmse:6.56791
# [26]	validation-rmse:6.56230
# [27]	validation-rmse:6.55841
# [28]	validation-rmse:6.55557
# [29]	validation-rmse:6.55308
# [30]	validation-rmse:6.55027
# [31]	validation-rmse:6.54842
# [32]	validation-rmse:6.54676
# [33]	validation-rmse:6.54419
# [34]	validation-rmse:6.54081
# [35]	validation-rmse:6.53994
# [36]	validation-rmse:6.53743
# [37]	validation-rmse:6.53577
# [38]	validation-rmse:6.53425
# [39]	validation-rmse:6.53283
# [40]	validation-rmse:6.53172
# [41]	validation-rmse:6.53100
# [42]	validation-rmse:6.52960
# [43]	validation-rmse:6.52879
# [44]	validation-rmse:6.52725
# [45]	validation-rmse:6.52549
# [46]	validation-rmse:6.52398
# [47]	validation-rmse:6.52260
# [48]	validation-rmse:6.52147
# [49]	validation-rmse:6.51975
# [50]	validation-rmse:6.51835
# [51]	validation-rmse:6.51704
# [52]	validation-rmse:6.51571
# [53]	validation-rmse:6.51439
# [54]	validation-rmse:6.51332
# [55]	validation-rmse:6.51210
# [56]	validation-rmse:6.51104
# [57]	validation-rmse:6.50925
# [58]	validation-rmse:6.50804
# [59]	validation-rmse:6.50672
# [60]	validation-rmse:6.50567
# [61]	validation-rmse:6.50498
# [62]	validation-rmse:6.50456
# [63]	validation-rmse:6.50366
# [64]	validation-rmse:6.50267
# [65]	validation-rmse:6.50210
# [66]	validation-rmse:6.50117
# [67]	validation-rmse:6.49999
# [68]	validation-rmse:6.49931
# [69]	validation-rmse:6.49848
# [70]	validation-rmse:6.49780
# [71]	validation-rmse:6.49641
# [72]	validation-rmse:6.49567
# [73]	validation-rmse:6.49430
# [74]	validation-rmse:6.49195
# [75]	validation-rmse:6.49093
# [76]	validation-rmse:6.48952
# [77]	validation-rmse:6.48903
# [78]	validation-rmse:6.48856
# [79]	validation-rmse:6.48724
# [80]	validation-rmse:6.48600
# [81]	validation-rmse:6.48473
# [82]	validation-rmse:6.48394
# [83]	validation-rmse:6.48288
# [84]	validation-rmse:6.48184
# [85]	validation-rmse:6.48103
# [86]	validation-rmse:6.47995
# [87]	validation-rmse:6.47907
# [88]	validation-rmse:6.47796
# [89]	validation-rmse:6.47728
# [90]	validation-rmse:6.47669
# [91]	validation-rmse:6.47578
# [92]	validation-rmse:6.47531
# [93]	validation-rmse:6.47368
# [94]	validation-rmse:6.47206
# [95]	validation-rmse:6.47134
# [96]	validation-rmse:6.46970
# [97]	validation-rmse:6.46886
# [98]	validation-rmse:6.46876
# [99]	validation-rmse:6.46788
# [100]	validation-rmse:6.46735
# [101]	validation-rmse:6.46645
# [102]	validation-rmse:6.46570
# [103]	validation-rmse:6.46487
# [104]	validation-rmse:6.46434
# [105]	validation-rmse:6.46339
# [106]	validation-rmse:6.46244
# [107]	validation-rmse:6.46187
# [108]	validation-rmse:6.46122
# [109]	validation-rmse:6.46025
# [110]	validation-rmse:6.45972
# [111]	validation-rmse:6.45903
# [112]	validation-rmse:6.45828
# [113]	validation-rmse:6.45778
# [114]	validation-rmse:6.45675
# [115]	validation-rmse:6.45616
# [116]	validation-rmse:6.45550
# [117]	validation-rmse:6.45505
# [118]	validation-rmse:6.45456
# [119]	validation-rmse:6.45379
# [120]	validation-rmse:6.45323
# [121]	validation-rmse:6.45220
# [122]	validation-rmse:6.45145
# [123]	validation-rmse:6.45047
# [124]	validation-rmse:6.44971
# [125]	validation-rmse:6.44903
# [126]	validation-rmse:6.44865
# [127]	validation-rmse:6.44815
# [128]	validation-rmse:6.44734
# [129]	validation-rmse:6.44670
# [130]	validation-rmse:6.44630
# [131]	validation-rmse:6.44601
# [132]	validation-rmse:6.44582
# [133]	validation-rmse:6.44518
# [134]	validation-rmse:6.44437
# [135]	validation-rmse:6.44368
# [136]	validation-rmse:6.44351
# [137]	validation-rmse:6.44299
# [138]	validation-rmse:6.44251
# [139]	validation-rmse:6.44208
# [140]	validation-rmse:6.44178
# [141]	validation-rmse:6.44091
# [142]	validation-rmse:6.44049
# [143]	validation-rmse:6.43966
# [144]	validation-rmse:6.43918
# [145]	validation-rmse:6.43866
# [146]	validation-rmse:6.43819
# [147]	validation-rmse:6.43773
# [148]	validation-rmse:6.43686
# [149]	validation-rmse:6.43619
# [150]	validation-rmse:6.43555
# [151]	validation-rmse:6.43529
# [152]	validation-rmse:6.43484
# [153]	validation-rmse:6.43369
# [154]	validation-rmse:6.43359
# [155]	validation-rmse:6.43265
# [156]	validation-rmse:6.43220
# [157]	validation-rmse:6.43217
# [158]	validation-rmse:6.43201
# [159]	validation-rmse:6.43141
# [160]	validation-rmse:6.43124
# [161]	validation-rmse:6.43064
# [162]	validation-rmse:6.43014
# [163]	validation-rmse:6.42955
# [164]	validation-rmse:6.42899
# [165]	validation-rmse:6.42874
# [166]	validation-rmse:6.42743
# [167]	validation-rmse:6.42643
# [168]	validation-rmse:6.42640
# [169]	validation-rmse:6.42595
# [170]	validation-rmse:6.42529
# [171]	validation-rmse:6.42493
# [172]	validation-rmse:6.42397
# [173]	validation-rmse:6.42359
# [174]	validation-rmse:6.42260
# [175]	validation-rmse:6.42188
# [176]	validation-rmse:6.42144
# [177]	validation-rmse:6.42093
# [178]	validation-rmse:6.41995
# [179]	validation-rmse:6.41965
# [180]	validation-rmse:6.41914
# [181]	validation-rmse:6.41803
# [182]	validation-rmse:6.41720
# [183]	validation-rmse:6.41713
# [184]	validation-rmse:6.41688
# [185]	validation-rmse:6.41663
# [186]	validation-rmse:6.41598
# [187]	validation-rmse:6.41516
# [188]	validation-rmse:6.41472
# [189]	validation-rmse:6.41402
# [190]	validation-rmse:6.41323
# [191]	validation-rmse:6.41269
# [192]	validation-rmse:6.41208
# [193]	validation-rmse:6.41152
# [194]	validation-rmse:6.41116
# [195]	validation-rmse:6.41069
# [196]	validation-rmse:6.41036
# [197]	validation-rmse:6.40985
# [198]	validation-rmse:6.40952
# [199]	validation-rmse:6.40916
# [200]	validation-rmse:6.40829
# [201]	validation-rmse:6.40784
# [202]	validation-rmse:6.40743
# [203]	validation-rmse:6.40704
# [204]	validation-rmse:6.40664
# [205]	validation-rmse:6.40601
# [206]	validation-rmse:6.40565
# [207]	validation-rmse:6.40521
# [208]	validation-rmse:6.40467
# [209]	validation-rmse:6.40391
# [210]	validation-rmse:6.40358
# [211]	validation-rmse:6.40314
# [212]	validation-rmse:6.40267
# [213]	validation-rmse:6.40221
# [214]	validation-rmse:6.40175
# [215]	validation-rmse:6.40084
# [216]	validation-rmse:6.40017
# [217]	validation-rmse:6.40012
# [218]	validation-rmse:6.39961
# [219]	validation-rmse:6.39926
# [220]	validation-rmse:6.39888
# [221]	validation-rmse:6.39867
# [222]	validation-rmse:6.39821
# [223]	validation-rmse:6.39754
# [224]	validation-rmse:6.39729
# [225]	validation-rmse:6.39653
# [226]	validation-rmse:6.39557
# [227]	validation-rmse:6.39535
# [228]	validation-rmse:6.39510
# [229]	validation-rmse:6.39459
# [230]	validation-rmse:6.39401
# [231]	validation-rmse:6.39387
# [232]	validation-rmse:6.39335
# [233]	validation-rmse:6.39301
# [234]	validation-rmse:6.39259
# [235]	validation-rmse:6.39230
# [236]	validation-rmse:6.39154
# [237]	validation-rmse:6.39124
# [238]	validation-rmse:6.39078
# [239]	validation-rmse:6.39040
# [240]	validation-rmse:6.39014
# [241]	validation-rmse:6.38974
# [242]	validation-rmse:6.38963
# [243]	validation-rmse:6.38913
# [244]	validation-rmse:6.38930
# [245]	validation-rmse:6.38925
# [246]	validation-rmse:6.38923
# [247]	validation-rmse:6.38915
# [248]	validation-rmse:6.38891
# [249]	validation-rmse:6.38839
# [250]	validation-rmse:6.38781
# [251]	validation-rmse:6.38779
# [252]	validation-rmse:6.38761
# [253]	validation-rmse:6.38738
# [254]	validation-rmse:6.38739
# [255]	validation-rmse:6.38718
# [256]	validation-rmse:6.38710
# [257]	validation-rmse:6.38665
# [258]	validation-rmse:6.38614
# [259]	validation-rmse:6.38575
# [260]	validation-rmse:6.38563
# [261]	validation-rmse:6.38544
# [262]	validation-rmse:6.38520
# [263]	validation-rmse:6.38509
# [264]	validation-rmse:6.38447
# [265]	validation-rmse:6.38447
# [266]	validation-rmse:6.38421
# [267]	validation-rmse:6.38377
# [268]	validation-rmse:6.38335
# [269]	validation-rmse:6.38319
# [270]	validation-rmse:6.38279
# [271]	validation-rmse:6.38246
# [272]	validation-rmse:6.38209
# [273]	validation-rmse:6.38178
# [274]	validation-rmse:6.38122
# [275]	validation-rmse:6.38084
# [276]	validation-rmse:6.38059
# [277]	validation-rmse:6.38039
# [278]	validation-rmse:6.38016
# [279]	validation-rmse:6.38023
# [280]	validation-rmse:6.37994
# [281]	validation-rmse:6.37964
# [282]	validation-rmse:6.37934
# [283]	validation-rmse:6.37903
# [284]	validation-rmse:6.37857
# [285]	validation-rmse:6.37822
# [286]	validation-rmse:6.37776
# [287]	validation-rmse:6.37748
# [288]	validation-rmse:6.37711
# [289]	validation-rmse:6.37686
# [290]	validation-rmse:6.37656
# [291]	validation-rmse:6.37631
# [292]	validation-rmse:6.37595
# [293]	validation-rmse:6.37548
# [294]	validation-rmse:6.37526
# [295]	validation-rmse:6.37487
# [296]	validation-rmse:6.37458
# [297]	validation-rmse:6.37408
# [298]	validation-rmse:6.37377
# [299]	validation-rmse:6.37325
# [300]	validation-rmse:6.37320
# [301]	validation-rmse:6.37295
# [302]	validation-rmse:6.37202
# [303]	validation-rmse:6.37178
# [304]	validation-rmse:6.37134
# [305]	validation-rmse:6.37106
# [306]	validation-rmse:6.37081
# [307]	validation-rmse:6.37047
# [308]	validation-rmse:6.37004
# [309]	validation-rmse:6.36980
# [310]	validation-rmse:6.36954
# [311]	validation-rmse:6.36924
# [312]	validation-rmse:6.36906
# [313]	validation-rmse:6.36883
# [314]	validation-rmse:6.36848
# [315]	validation-rmse:6.36844
# [316]	validation-rmse:6.36806
# [317]	validation-rmse:6.36777
# [318]	validation-rmse:6.36720
# [319]	validation-rmse:6.36690
# [320]	validation-rmse:6.36667
# [321]	validation-rmse:6.36659
# [322]	validation-rmse:6.36645
# [323]	validation-rmse:6.36612
# [324]	validation-rmse:6.36529
# [325]	validation-rmse:6.36474
# [326]	validation-rmse:6.36467
# [327]	validation-rmse:6.36410
# [328]	validation-rmse:6.36392
# [329]	validation-rmse:6.36333
# [330]	validation-rmse:6.36318
# [331]	validation-rmse:6.36284
# [332]	validation-rmse:6.36275
# [333]	validation-rmse:6.36247
# [334]	validation-rmse:6.36219
# [335]	validation-rmse:6.36195
# [336]	validation-rmse:6.36138
# [337]	validation-rmse:6.36109
# [338]	validation-rmse:6.36102
# [339]	validation-rmse:6.36073
# [340]	validation-rmse:6.36049
# [341]	validation-rmse:6.36007
# [342]	validation-rmse:6.35995
# [343]	validation-rmse:6.35973
# [344]	validation-rmse:6.35916
# [345]	validation-rmse:6.35896
# [346]	validation-rmse:6.35875
# [347]	validation-rmse:6.35800
# [348]	validation-rmse:6.35785
# [349]	validation-rmse:6.35735
# [350]	validation-rmse:6.35667
# [351]	validation-rmse:6.35667
# [352]	validation-rmse:6.35628
# [353]	validation-rmse:6.35566
# [354]	validation-rmse:6.35555
# [355]	validation-rmse:6.35522
# [356]	validation-rmse:6.35506
# [357]	validation-rmse:6.35485
# [358]	validation-rmse:6.35451
# [359]	validation-rmse:6.35448
# [360]	validation-rmse:6.35421
# [361]	validation-rmse:6.35396
# [362]	validation-rmse:6.35400
# [363]	validation-rmse:6.35374
# [364]	validation-rmse:6.35349
# [365]	validation-rmse:6.35348
# [366]	validation-rmse:6.35324
# [367]	validation-rmse:6.35296
# [368]	validation-rmse:6.35260
# [369]	validation-rmse:6.35229
# [370]	validation-rmse:6.35219
# [371]	validation-rmse:6.35197
# [372]	validation-rmse:6.35186
# [373]	validation-rmse:6.35150
# [374]	validation-rmse:6.35127
# [375]	validation-rmse:6.35101
# [376]	validation-rmse:6.35096
# [377]	validation-rmse:6.34993
# [378]	validation-rmse:6.34992
# [379]	validation-rmse:6.34974
# [380]	validation-rmse:6.34921
# [381]	validation-rmse:6.34901
# [382]	validation-rmse:6.34878
# [383]	validation-rmse:6.34855
# [384]	validation-rmse:6.34824
# [385]	validation-rmse:6.34802
# [386]	validation-rmse:6.34780
# [387]	validation-rmse:6.34763
# [388]	validation-rmse:6.34741
# [389]	validation-rmse:6.34711
# [390]	validation-rmse:6.34689
# [391]	validation-rmse:6.34675
# [392]	validation-rmse:6.34688
# [393]	validation-rmse:6.34661
# [394]	validation-rmse:6.34610
# [395]	validation-rmse:6.34590
# [396]	validation-rmse:6.34567
# [397]	validation-rmse:6.34555
# [398]	validation-rmse:6.34535
# [399]	validation-rmse:6.34551
# [400]	validation-rmse:6.34547
# [401]	validation-rmse:6.34525
# [402]	validation-rmse:6.34473
# [403]	validation-rmse:6.34447
# [404]	validation-rmse:6.34478
# [405]	validation-rmse:6.34462
# [406]	validation-rmse:6.34468
# [407]	validation-rmse:6.34445
# [408]	validation-rmse:6.34437
# [409]	validation-rmse:6.34401
# [410]	validation-rmse:6.34372
# [411]	validation-rmse:6.34355
# [412]	validation-rmse:6.34358
# [413]	validation-rmse:6.34346
# [414]	validation-rmse:6.34314
# [415]	validation-rmse:6.34318
# [416]	validation-rmse:6.34285
# [417]	validation-rmse:6.34293
# [418]	validation-rmse:6.34280
# [419]	validation-rmse:6.34253
# [420]	validation-rmse:6.34223
# [421]	validation-rmse:6.34167
# [422]	validation-rmse:6.34137
# [423]	validation-rmse:6.34129
# [424]	validation-rmse:6.34113
# [425]	validation-rmse:6.34115
# [426]	validation-rmse:6.34097
# [427]	validation-rmse:6.34091
# [428]	validation-rmse:6.34082
# [429]	validation-rmse:6.34059
# [430]	validation-rmse:6.34033
# [431]	validation-rmse:6.33958
# [432]	validation-rmse:6.33964
# [433]	validation-rmse:6.33978
# [434]	validation-rmse:6.33969
# [435]	validation-rmse:6.33944
# [436]	validation-rmse:6.33906
# [437]	validation-rmse:6.33892
# [438]	validation-rmse:6.33886
# [439]	validation-rmse:6.33870
# [440]	validation-rmse:6.33845
# [441]	validation-rmse:6.33827
# [442]	validation-rmse:6.33804
# [443]	validation-rmse:6.33776
# [444]	validation-rmse:6.33739
# [445]	validation-rmse:6.33718
# [446]	validation-rmse:6.33722
# [447]	validation-rmse:6.33718
# [448]	validation-rmse:6.33726
# [449]	validation-rmse:6.33690
# [450]	validation-rmse:6.33737
# [451]	validation-rmse:6.33721
# [452]	validation-rmse:6.33714
# [453]	validation-rmse:6.33668
# [454]	validation-rmse:6.33655
# [455]	validation-rmse:6.33638
# [456]	validation-rmse:6.33624
# [457]	validation-rmse:6.33626
# [458]	validation-rmse:6.33610
# [459]	validation-rmse:6.33602
# [460]	validation-rmse:6.33595
# [461]	validation-rmse:6.33597
# [462]	validation-rmse:6.33572
# [463]	validation-rmse:6.33538
# [464]	validation-rmse:6.33479
# [465]	validation-rmse:6.33464
# [466]	validation-rmse:6.33437
# [467]	validation-rmse:6.33427
# [468]	validation-rmse:6.33409
# [469]	validation-rmse:6.33403
# [470]	validation-rmse:6.33395
# [471]	validation-rmse:6.33364
# [472]	validation-rmse:6.33346
# [473]	validation-rmse:6.33306
# [474]	validation-rmse:6.33311
# [475]	validation-rmse:6.33299
# [476]	validation-rmse:6.33267
# [477]	validation-rmse:6.33241
# [478]	validation-rmse:6.33235
# [479]	validation-rmse:6.33246
# [480]	validation-rmse:6.33221
# [481]	validation-rmse:6.33229
# [482]	validation-rmse:6.33216
# [483]	validation-rmse:6.33221
# [484]	validation-rmse:6.33222
# [485]	validation-rmse:6.33198
# [486]	validation-rmse:6.33198
# [487]	validation-rmse:6.33169
# [488]	validation-rmse:6.33156
# [489]	validation-rmse:6.33155
# [490]	validation-rmse:6.33147
# [491]	validation-rmse:6.33132
# [492]	validation-rmse:6.33135
# [493]	validation-rmse:6.33105
# [494]	validation-rmse:6.33086
# [495]	validation-rmse:6.33042
# [496]	validation-rmse:6.33010
# [497]	validation-rmse:6.33012
# [498]	validation-rmse:6.32995
# [499]	validation-rmse:6.32968
# [500]	validation-rmse:6.32917
# [501]	validation-rmse:6.32884
# [502]	validation-rmse:6.32869
# [503]	validation-rmse:6.32847
# [504]	validation-rmse:6.32819
# [505]	validation-rmse:6.32785
# [506]	validation-rmse:6.32768
# [507]	validation-rmse:6.32730
# [508]	validation-rmse:6.32726
# [509]	validation-rmse:6.32722
# [510]	validation-rmse:6.32700
# [511]	validation-rmse:6.32695
# [512]	validation-rmse:6.32694
# [513]	validation-rmse:6.32667
# [514]	validation-rmse:6.32674
# [515]	validation-rmse:6.32664
# [516]	validation-rmse:6.32667
# [517]	validation-rmse:6.32661
# [518]	validation-rmse:6.32684
# [519]	validation-rmse:6.32690
# [520]	validation-rmse:6.32643
# [521]	validation-rmse:6.32610
# [522]	validation-rmse:6.32589
# [523]	validation-rmse:6.32578
# [524]	validation-rmse:6.32536
# [525]	validation-rmse:6.32492
# [526]	validation-rmse:6.32495
# [527]	validation-rmse:6.32454
# [528]	validation-rmse:6.32446
# [529]	validation-rmse:6.32425
# [530]	validation-rmse:6.32395
# [531]	validation-rmse:6.32375
# [532]	validation-rmse:6.32356
# [533]	validation-rmse:6.32361
# [534]	validation-rmse:6.32355
# [535]	validation-rmse:6.32358
# [536]	validation-rmse:6.32327
# [537]	validation-rmse:6.32325
# [538]	validation-rmse:6.32281
# [539]	validation-rmse:6.32270
# [540]	validation-rmse:6.32253
# [541]	validation-rmse:6.32247
# [542]	validation-rmse:6.32251
# [543]	validation-rmse:6.32267
# [544]	validation-rmse:6.32246
# [545]	validation-rmse:6.32220
# [546]	validation-rmse:6.32221
# [547]	validation-rmse:6.32213
# [548]	validation-rmse:6.32210
# [549]	validation-rmse:6.32200
# [550]	validation-rmse:6.32178
# [551]	validation-rmse:6.32168
# [552]	validation-rmse:6.32171
# [553]	validation-rmse:6.32151
# [554]	validation-rmse:6.32140
# [555]	validation-rmse:6.32150
# [556]	validation-rmse:6.32131
# [557]	validation-rmse:6.32121
# [558]	validation-rmse:6.32085
# [559]	validation-rmse:6.32081
# [560]	validation-rmse:6.32076
# [561]	validation-rmse:6.32059
# [562]	validation-rmse:6.32040
# [563]	validation-rmse:6.32041
# [564]	validation-rmse:6.32021
# [565]	validation-rmse:6.32015
# [566]	validation-rmse:6.32021
# [567]	validation-rmse:6.32015
# [568]	validation-rmse:6.31988
# [569]	validation-rmse:6.31971
# [570]	validation-rmse:6.31967
# [571]	validation-rmse:6.31940
# [572]	validation-rmse:6.31968
# [573]	validation-rmse:6.31961
# [574]	validation-rmse:6.31959
# [575]	validation-rmse:6.31945
# [576]	validation-rmse:6.31906
# [577]	validation-rmse:6.31904
# [578]	validation-rmse:6.31892
# [579]	validation-rmse:6.31883
# [580]	validation-rmse:6.31863
# [581]	validation-rmse:6.31856
# [582]	validation-rmse:6.31862
# [583]	validation-rmse:6.31846
# [584]	validation-rmse:6.31836
# [585]	validation-rmse:6.31813
# [586]	validation-rmse:6.31781
# [587]	validation-rmse:6.31765
# [588]	validation-rmse:6.31752
# [589]	validation-rmse:6.31760
# [590]	validation-rmse:6.31747
# [591]	validation-rmse:6.31712
# [592]	validation-rmse:6.31691
# [593]	validation-rmse:6.31671
# [594]	validation-rmse:6.31663
# [595]	validation-rmse:6.31650
# [596]	validation-rmse:6.31645
# [597]	validation-rmse:6.31640
# [598]	validation-rmse:6.31623
# [599]	validation-rmse:6.31627
# [600]	validation-rmse:6.31611
# [601]	validation-rmse:6.31590
# [602]	validation-rmse:6.31597
# [603]	validation-rmse:6.31573
# [604]	validation-rmse:6.31561
# [605]	validation-rmse:6.31553
# [606]	validation-rmse:6.31576
# [607]	validation-rmse:6.31560
# [608]	validation-rmse:6.31540
# [609]	validation-rmse:6.31543
# [610]	validation-rmse:6.31548
# [611]	validation-rmse:6.31536
# [612]	validation-rmse:6.31527
# [613]	validation-rmse:6.31528
# [614]	validation-rmse:6.31503
# [615]	validation-rmse:6.31505
# [616]	validation-rmse:6.31498
# [617]	validation-rmse:6.31503
# [618]	validation-rmse:6.31471
# [619]	validation-rmse:6.31481
# [620]	validation-rmse:6.31455
# [621]	validation-rmse:6.31434
# [622]	validation-rmse:6.31448
# [623]	validation-rmse:6.31423
# [624]	validation-rmse:6.31405
# [625]	validation-rmse:6.31439
# [626]	validation-rmse:6.31428
# [627]	validation-rmse:6.31353
# [628]	validation-rmse:6.31333
# [629]	validation-rmse:6.31314
# [630]	validation-rmse:6.31323
# [631]	validation-rmse:6.31338
# [632]	validation-rmse:6.31328
# [633]	validation-rmse:6.31333
# [634]	validation-rmse:6.31334
# [635]	validation-rmse:6.31308
# [636]	validation-rmse:6.31298
# [637]	validation-rmse:6.31295
# [638]	validation-rmse:6.31306
# [639]	validation-rmse:6.31307
# [640]	validation-rmse:6.31294
# [641]	validation-rmse:6.31292
# [642]	validation-rmse:6.31270
# [643]	validation-rmse:6.31269
# [644]	validation-rmse:6.31257
# [645]	validation-rmse:6.31241
# [646]	validation-rmse:6.31227
# [647]	validation-rmse:6.31220
# [648]	validation-rmse:6.31219
# [649]	validation-rmse:6.31249
# [650]	validation-rmse:6.31238
# [651]	validation-rmse:6.31236
# [652]	validation-rmse:6.31212
# [653]	validation-rmse:6.31186
# [654]	validation-rmse:6.31175
# [655]	validation-rmse:6.31189
# [656]	validation-rmse:6.31200
# [657]	validation-rmse:6.31178
# [658]	validation-rmse:6.31141
# [659]	validation-rmse:6.31114
# [660]	validation-rmse:6.31093
# [661]	validation-rmse:6.31048
# [662]	validation-rmse:6.31043
# [663]	validation-rmse:6.31014
# [664]	validation-rmse:6.31021
# [665]	validation-rmse:6.30990
# [666]	validation-rmse:6.30993
# [667]	validation-rmse:6.31002
# [668]	validation-rmse:6.30993
# [669]	validation-rmse:6.30975
# [670]	validation-rmse:6.30970
# [671]	validation-rmse:6.30958
# [672]	validation-rmse:6.30952
# [673]	validation-rmse:6.30928
# [674]	validation-rmse:6.30911
# [675]	validation-rmse:6.30925
# [676]	validation-rmse:6.30892
# [677]	validation-rmse:6.30894
# [678]	validation-rmse:6.30896
# [679]	validation-rmse:6.30877
# [680]	validation-rmse:6.30869
# [681]	validation-rmse:6.30864
# [682]	validation-rmse:6.30871
# [683]	validation-rmse:6.30866
# [684]	validation-rmse:6.30911
# [685]	validation-rmse:6.30893
# [686]	validation-rmse:6.30900
# [687]	validation-rmse:6.30914
# [688]	validation-rmse:6.30883
# [689]	validation-rmse:6.30873
# [690]	validation-rmse:6.30859
# [691]	validation-rmse:6.30853
# [692]	validation-rmse:6.30854
# [693]	validation-rmse:6.30845
# [694]	validation-rmse:6.30834
# [695]	validation-rmse:6.30848
# [696]	validation-rmse:6.30820
# [697]	validation-rmse:6.30818
# [698]	validation-rmse:6.30790
# [699]	validation-rmse:6.30786
# [700]	validation-rmse:6.30781
# [701]	validation-rmse:6.30787
# [702]	validation-rmse:6.30792
# [703]	validation-rmse:6.30785
# [704]	validation-rmse:6.30774
# [705]	validation-rmse:6.30767
# [706]	validation-rmse:6.30761
# [707]	validation-rmse:6.30754
# [708]	validation-rmse:6.30740
# [709]	validation-rmse:6.30720
# [710]	validation-rmse:6.30693
# [711]	validation-rmse:6.30689
# [712]	validation-rmse:6.30675
# [713]	validation-rmse:6.30666
# [714]	validation-rmse:6.30667
# [715]	validation-rmse:6.30657
# [716]	validation-rmse:6.30670
# [717]	validation-rmse:6.30640
# [718]	validation-rmse:6.30595
# [719]	validation-rmse:6.30598
# [720]	validation-rmse:6.30607
# [721]	validation-rmse:6.30617
# [722]	validation-rmse:6.30618
# [723]	validation-rmse:6.30611
# [724]	validation-rmse:6.30612
# [725]	validation-rmse:6.30610
# [726]	validation-rmse:6.30624
# [727]	validation-rmse:6.30607
# [728]	validation-rmse:6.30600
# [729]	validation-rmse:6.30584
# [730]	validation-rmse:6.30553
# [731]	validation-rmse:6.30542
# [732]	validation-rmse:6.30521
# [733]	validation-rmse:6.30508
# [734]	validation-rmse:6.30498
# [735]	validation-rmse:6.30498
# [736]	validation-rmse:6.30499
# [737]	validation-rmse:6.30484
# [738]	validation-rmse:6.30453
# [739]	validation-rmse:6.30449
# [740]	validation-rmse:6.30440
# [741]	validation-rmse:6.30440
# [742]	validation-rmse:6.30422
# [743]	validation-rmse:6.30452
# [744]	validation-rmse:6.30449
# [745]	validation-rmse:6.30446
# [746]	validation-rmse:6.30438
# [747]	validation-rmse:6.30418
# [748]	validation-rmse:6.30413
# [749]	validation-rmse:6.30394
# [750]	validation-rmse:6.30391
# [751]	validation-rmse:6.30376
# [752]	validation-rmse:6.30352
# [753]	validation-rmse:6.30337
# [754]	validation-rmse:6.30318
# [755]	validation-rmse:6.30321
# [756]	validation-rmse:6.30332
# [757]	validation-rmse:6.30321
# [758]	validation-rmse:6.30310
# [759]	validation-rmse:6.30295
# [760]	validation-rmse:6.30281
# [761]	validation-rmse:6.30254
# [762]	validation-rmse:6.30265
# [763]	validation-rmse:6.30239
# [764]	validation-rmse:6.30234
# [765]	validation-rmse:6.30235
# [766]	validation-rmse:6.30226
# [767]	validation-rmse:6.30222
# [768]	validation-rmse:6.30212
# [769]	validation-rmse:6.30204
# [770]	validation-rmse:6.30221
# [771]	validation-rmse:6.30245
# [772]	validation-rmse:6.30239
# [773]	validation-rmse:6.30228
# [774]	validation-rmse:6.30229
# [775]	validation-rmse:6.30221
# [776]	validation-rmse:6.30232
# [777]	validation-rmse:6.30240
# [778]	validation-rmse:6.30241
# [779]	validation-rmse:6.30236
# [780]	validation-rmse:6.30234
# [781]	validation-rmse:6.30241
# [782]	validation-rmse:6.30217
# [783]	validation-rmse:6.30161
# [784]	validation-rmse:6.30150
# [785]	validation-rmse:6.30154
# [786]	validation-rmse:6.30133
# [787]	validation-rmse:6.30152
# [788]	validation-rmse:6.30146
# [789]	validation-rmse:6.30138
# [790]	validation-rmse:6.30107
# [791]	validation-rmse:6.30087
# [792]	validation-rmse:6.30073
# [793]	validation-rmse:6.30054
# [794]	validation-rmse:6.30020
# [795]	validation-rmse:6.30001
# [796]	validation-rmse:6.30001
# [797]	validation-rmse:6.29989
# [798]	validation-rmse:6.29986
# [799]	validation-rmse:6.29979
# [800]	validation-rmse:6.29973
# [801]	validation-rmse:6.29953
# [802]	validation-rmse:6.29939
# [803]	validation-rmse:6.29925
# [804]	validation-rmse:6.29862
# [805]	validation-rmse:6.29860
# [806]	validation-rmse:6.29859
# [807]	validation-rmse:6.29852
# [808]	validation-rmse:6.29847
# [809]	validation-rmse:6.29849
# [810]	validation-rmse:6.29849
# [811]	validation-rmse:6.29856
# [812]	validation-rmse:6.29860
# [813]	validation-rmse:6.29853
# [814]	validation-rmse:6.29856
# [815]	validation-rmse:6.29786
# [816]	validation-rmse:6.29768
# [817]	validation-rmse:6.29761
# [818]	validation-rmse:6.29764
# [819]	validation-rmse:6.29746
# [820]	validation-rmse:6.29725
# [821]	validation-rmse:6.29778
# [822]	validation-rmse:6.29784
# [823]	validation-rmse:6.29783
# [824]	validation-rmse:6.29783
# [825]	validation-rmse:6.29775
# [826]	validation-rmse:6.29767
# [827]	validation-rmse:6.29755
# [828]	validation-rmse:6.29741
# [829]	validation-rmse:6.29742
# [830]	validation-rmse:6.29746
# [831]	validation-rmse:6.29721
# [832]	validation-rmse:6.29706
# [833]	validation-rmse:6.29712
# [834]	validation-rmse:6.29718
# [835]	validation-rmse:6.29718
# [836]	validation-rmse:6.29719
# [837]	validation-rmse:6.29734
# [838]	validation-rmse:6.29723
# [839]	validation-rmse:6.29720
# [840]	validation-rmse:6.29716
# [841]	validation-rmse:6.29714
# [842]	validation-rmse:6.29726
# [843]	validation-rmse:6.29709
# [844]	validation-rmse:6.29720
# [845]	validation-rmse:6.29713
# [846]	validation-rmse:6.29740
# [847]	validation-rmse:6.29733
# [848]	validation-rmse:6.29744
# [849]	validation-rmse:6.29749
# [850]	validation-rmse:6.29758
# [851]	validation-rmse:6.29748
# [852]	validation-rmse:6.29714
# [853]	validation-rmse:6.29714
# [854]	validation-rmse:6.29706
# [855]	validation-rmse:6.29706
# [856]	validation-rmse:6.29663
# [857]	validation-rmse:6.29660
# [858]	validation-rmse:6.29655
# [859]	validation-rmse:6.29643
# [860]	validation-rmse:6.29644
# [861]	validation-rmse:6.29637
# [862]	validation-rmse:6.29623
# [863]	validation-rmse:6.29625
# [864]	validation-rmse:6.29622
# [865]	validation-rmse:6.29603
# [866]	validation-rmse:6.29599
# [867]	validation-rmse:6.29584
# [868]	validation-rmse:6.29588
# [869]	validation-rmse:6.29600
# [870]	validation-rmse:6.29606
# [871]	validation-rmse:6.29595
# [872]	validation-rmse:6.29594
# [873]	validation-rmse:6.29591
# [874]	validation-rmse:6.29585
# [875]	validation-rmse:6.29584
# [876]	validation-rmse:6.29570
# [877]	validation-rmse:6.29576
# [878]	validation-rmse:6.29585
# [879]	validation-rmse:6.29594
# [880]	validation-rmse:6.29578
# [881]	validation-rmse:6.29581
# [882]	validation-rmse:6.29536
# [883]	validation-rmse:6.29545
# [884]	validation-rmse:6.29541
# [885]	validation-rmse:6.29534
# [886]	validation-rmse:6.29532
# [887]	validation-rmse:6.29531
# [888]	validation-rmse:6.29501
# [889]	validation-rmse:6.29501
# [890]	validation-rmse:6.29482
# [891]	validation-rmse:6.29471
# [892]	validation-rmse:6.29469
# [893]	validation-rmse:6.29474
# [894]	validation-rmse:6.29462
# [895]	validation-rmse:6.29454
# [896]	validation-rmse:6.29457
# [897]	validation-rmse:6.29450
# [898]	validation-rmse:6.29462
# [899]	validation-rmse:6.29458
# [900]	validation-rmse:6.29456
# [901]	validation-rmse:6.29458
# [902]	validation-rmse:6.29453
# [903]	validation-rmse:6.29459
# [904]	validation-rmse:6.29445
# [905]	validation-rmse:6.29430
# [906]	validation-rmse:6.29451
# [907]	validation-rmse:6.29458
# [908]	validation-rmse:6.29395
# [909]	validation-rmse:6.29400
# [910]	validation-rmse:6.29408
# [911]	validation-rmse:6.29467
# [912]	validation-rmse:6.29459
# [913]	validation-rmse:6.29459
# [914]	validation-rmse:6.29472
# [915]	validation-rmse:6.29478
# [916]	validation-rmse:6.29474
# [917]	validation-rmse:6.29466
# [918]	validation-rmse:6.29462
# [919]	validation-rmse:6.29468
# [920]	validation-rmse:6.29471
# [921]	validation-rmse:6.29460
# [922]	validation-rmse:6.29474
# [923]	validation-rmse:6.29451
# [924]	validation-rmse:6.29438
# [925]	validation-rmse:6.29450
# [926]	validation-rmse:6.29428
# [927]	validation-rmse:6.29422
# [928]	validation-rmse:6.29402
# [929]	validation-rmse:6.29394
# [930]	validation-rmse:6.29385
# [931]	validation-rmse:6.29369
# [932]	validation-rmse:6.29357
# [933]	validation-rmse:6.29381
# [934]	validation-rmse:6.29387
# [935]	validation-rmse:6.29358
# [936]	validation-rmse:6.29365
# [937]	validation-rmse:6.29373
# [938]	validation-rmse:6.29372
# [939]	validation-rmse:6.29367
# [940]	validation-rmse:6.29358
# [941]	validation-rmse:6.29364
# [942]	validation-rmse:6.29364
# [943]	validation-rmse:6.29368
# [944]	validation-rmse:6.29349
# [945]	validation-rmse:6.29362
# [946]	validation-rmse:6.29369
# [947]	validation-rmse:6.29379
# [948]	validation-rmse:6.29385
# [949]	validation-rmse:6.29365
# [950]	validation-rmse:6.29369
# [951]	validation-rmse:6.29355
# [952]	validation-rmse:6.29353
# [953]	validation-rmse:6.29336
# [954]	validation-rmse:6.29328
# [955]	validation-rmse:6.29332
# [956]	validation-rmse:6.29326
# [957]	validation-rmse:6.29312
# [958]	validation-rmse:6.29314
# [959]	validation-rmse:6.29274
# [960]	validation-rmse:6.29280
# [961]	validation-rmse:6.29288
# [962]	validation-rmse:6.29293
# [963]	validation-rmse:6.29286
# [964]	validation-rmse:6.29279
# [965]	validation-rmse:6.29292
# [966]	validation-rmse:6.29297
# [967]	validation-rmse:6.29266
# [968]	validation-rmse:6.29172
# [969]	validation-rmse:6.29178
# [970]	validation-rmse:6.29185
# [971]	validation-rmse:6.29185
# [972]	validation-rmse:6.29200
# [973]	validation-rmse:6.29173
# [974]	validation-rmse:6.29141
# [975]	validation-rmse:6.29130
# [976]	validation-rmse:6.29129
# [977]	validation-rmse:6.29121
# [978]	validation-rmse:6.29114
# [979]	validation-rmse:6.29117
# [980]	validation-rmse:6.29122
# [981]	validation-rmse:6.29129
# [982]	validation-rmse:6.29133
# [983]	validation-rmse:6.29133
# [984]	validation-rmse:6.29129
# [985]	validation-rmse:6.29128
# [986]	validation-rmse:6.29150
# [987]	validation-rmse:6.29155
# [988]	validation-rmse:6.29151
# [989]	validation-rmse:6.29151
# [990]	validation-rmse:6.29153
# [991]	validation-rmse:6.29151
# [992]	validation-rmse:6.29143
# [993]	validation-rmse:6.29123
# [994]	validation-rmse:6.29124
# [995]	validation-rmse:6.29116
# [996]	validation-rmse:6.29103
# [997]	validation-rmse:6.29098
# [998]	validation-rmse:6.29093
# [999]	validation-rmse:6.29096
# C:\Python311\Lib\site-packages\_distutils_hack\__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# C:\Python311\Lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %%
# making pandas dataframe prediction

logged_model = 'runs:/eb7e043a05c24fa88d057919d46c3435/models_mlflow'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)
# Out:
# [15:14:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: eb7e043a05c24fa88d057919d46c3435

# %%
xgboost_model = mlflow.xgboost.load_model(logged_model)
xgboost_model
# Out:
# [15:15:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.

# %%
y_pred = xgboost_model.predict(valid)

# %%
y_pred
# Out:
# array([15.18813  ,  7.2145815, 13.495876 , ..., 13.663579 ,  6.675244 ,
#         8.268747 ], dtype=float32)

# %% [markdown]
# ### **Other Regressors**

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):
    with mlflow.start_run():
        mlflow.log_param("train_data-path", "data/green_tripdata_2021-01.parquet")
        mlflow.log_param("valid_data-path", "data/green_tripdata_2021-02.parquet")
        mlflow.log_artifact('model/preprocessor.b', artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
# Out:
# 2023/12/21 17:04:03 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "C:\Python311\Lib\site-packages\_distutils_hack\__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/12/21 17:04:03 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "C:\Python311\Lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils."
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[41], line 4
#       1 from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
#       2 from sklearn.svm import LinearSVR
# ----> 4 mlflow.sklearn.autolog()
#       6 for model_class in (RandomForestRegressor, GrandientBoostingRegressor, ExtraTreesRegressor, LinearSVR):
#       7     with mlflow.start_run():
#
# File C:\Python311\Lib\site-packages\mlflow\utils\autologging_utils\__init__.py:424, in autologging_integration.<locals>.wrapper.<locals>.autolog(*args, **kwargs)
#     405 with set_mlflow_events_and_warnings_behavior_globally(
#     406     # MLflow warnings emitted during autologging setup / enablement are likely
#     407     # actionable and relevant to the user, so they should be emitted as normal
#    (...)
#     420     disable_warnings=is_silent_mode,
#     421 ):
#     422     _check_and_log_warning_for_unsupported_package_versions(name)
# --> 424     return _autolog(*args, **kwargs)
#
# File C:\Python311\Lib\site-packages\mlflow\sklearn\__init__.py:1261, in autolog(log_input_examples, log_model_signatures, log_models, log_datasets, disable, exclusive, disable_for_unsupported_versions, silent, max_tuning_runs, log_post_training_metrics, serialization_format, registered_model_name, pos_label, extra_tags)
#     976 @autologging_integration(FLAVOR_NAME)
#     977 def autolog(
#     978     log_input_examples=False,
#    (...)
#     991     extra_tags=None,
#     992 ):  # pylint: disable=unused-argument
#     993     """
#     994     Enables (or disables) and configures autologging for scikit-learn estimators.
#     995
#    (...)
#    1259     :param extra_tags: A dictionary of extra tags to set on each managed run created by autologging.
#    1260     """
# -> 1261     _autolog(
#    1262         flavor_name=FLAVOR_NAME,
#    1263         log_input_examples=log_input_examples,
#    1264         log_model_signatures=log_model_signatures,
#    1265         log_models=log_models,
#    1266         log_datasets=log_datasets,
#    1267         disable=disable,
#    1268         exclusive=exclusive,
#    1269         disable_for_unsupported_versions=disable_for_unsupported_versions,
#    1270         silent=silent,
#    1271         max_tuning_runs=max_tuning_runs,
#    1272         log_post_training_metrics=log_post_training_metrics,
#    1273         serialization_format=serialization_format,
#    1274         pos_label=pos_label,
#    1275         extra_tags=extra_tags,
#    1276     )
#
# File C:\Python311\Lib\site-packages\mlflow\sklearn\__init__.py:1822, in _autolog(flavor_name, log_input_examples, log_model_signatures, log_models, log_datasets, disable, exclusive, disable_for_unsupported_versions, silent, max_tuning_runs, log_post_training_metrics, serialization_format, pos_label, extra_tags)
#    1820     allow_children_patch = True
#    1821 else:
# -> 1822     estimators_to_patch = _gen_estimators_to_patch()
#    1823     patched_fit_impl = fit_mlflow
#    1824     allow_children_patch = False
#
# File C:\Python311\Lib\site-packages\mlflow\sklearn\__init__.py:98, in _gen_estimators_to_patch()
#      92 def _gen_estimators_to_patch():
#      93     from mlflow.sklearn.utils import (
#      94         _all_estimators,
#      95         _get_meta_estimators_for_autologging,
#      96     )
# ---> 98     _, estimators_to_patch = zip(*_all_estimators())
#      99     # Ensure that relevant meta estimators (e.g. GridSearchCV, Pipeline) are selected
#     100     # for patching if they are not already included in the output of `all_estimators()`
#     101     estimators_to_patch = set(estimators_to_patch).union(
#     102         set(_get_meta_estimators_for_autologging())
#     103     )
#
# File C:\Python311\Lib\site-packages\mlflow\sklearn\utils.py:858, in _all_estimators()
#     855 try:
#     856     from sklearn.utils import all_estimators
# --> 858     return all_estimators()
#     859 except ImportError:
#     860     return _backported_all_estimators()
#
# File C:\Python311\Lib\site-packages\sklearn\utils\discovery.py:63, in all_estimators(type_filter)
#      60 # Ignore deprecation warnings triggered at import time and from walking
#      61 # packages
#      62 with ignore_warnings(category=FutureWarning):
# ---> 63     for _, module_name, _ in pkgutil.walk_packages(path=[root], prefix="sklearn."):
#      64         module_parts = module_name.split(".")
#      65         if (
#      66             any(part in _MODULE_TO_IGNORE for part in module_parts)
#      67             or "._" in module_name
#      68         ):
#
# File C:\Python311\Lib\pkgutil.py:92, in walk_packages(path, prefix, onerror)
#      90 if info.ispkg:
#      91     try:
# ---> 92         __import__(info.name)
#      93     except ImportError:
#      94         if onerror is not None:
#
# File C:\Python311\Lib\site-packages\sklearn\_build_utils\__init__.py:15
#      13 from .._min_dependencies import CYTHON_MIN_VERSION
#      14 from ..externals._packaging.version import parse
# ---> 15 from .openmp_helpers import check_openmp_support
#      16 from .pre_build_helpers import basic_check_build
#      18 DEFAULT_ROOT = "sklearn"
#
# File C:\Python311\Lib\site-packages\sklearn\_build_utils\openmp_helpers.py:12
#       9 import textwrap
#      10 import warnings
# ---> 12 from .pre_build_helpers import compile_test_program
#      15 def get_openmp_flag():
#      16     if sys.platform == "win32":
#
# File C:\Python311\Lib\site-packages\sklearn\_build_utils\pre_build_helpers.py:10
#       7 import tempfile
#       8 import textwrap
# ---> 10 from setuptools.command.build_ext import customize_compiler, new_compiler
#      13 def compile_test_program(code, extra_preargs=None, extra_postargs=None):
#      14     """Check that some C code can be compiled and run"""
#
# File C:\Python311\Lib\site-packages\setuptools\__init__.py:7
#       4 import os
#       5 import re
# ----> 7 import _distutils_hack.override  # noqa: F401
#       9 import distutils.core
#      10 from distutils.errors import DistutilsOptionError
#
# File C:\Python311\Lib\site-packages\_distutils_hack\override.py:1
# ----> 1 __import__('_distutils_hack').do_override()
#
# File C:\Python311\Lib\site-packages\_distutils_hack\__init__.py:77, in do_override()
#      75 if enabled():
#      76     warn_distutils_present()
# ---> 77     ensure_local_distutils()
#
# File C:\Python311\Lib\site-packages\_distutils_hack\__init__.py:64, in ensure_local_distutils()
#      62 # check that submodules load as expected
#      63 core = importlib.import_module('distutils.core')
# ---> 64 assert '_distutils' in core.__file__, core.__file__
#      65 assert 'setuptools._distutils.log' not in sys.modules
#
# AssertionError: C:\Python311\Lib\distutils\core.py
